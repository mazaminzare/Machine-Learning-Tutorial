# %%
import gym

env = gym.make('CartPole-v1')

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import gym

# Initialize environment
env = gym.make('CartPole-v1')

# GAIL: Generator and Discriminator Networks
class Generator(tf.keras.Model):
    def __init__(self):
        super(Generator, self).__init__()
        self.dense1 = layers.Dense(24, activation='relu')
        self.dense2 = layers.Dense(24, activation='relu')
        self.output_layer = layers.Dense(env.action_space.n, activation='softmax')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.output_layer(x)

class Discriminator(tf.keras.Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.dense1 = layers.Dense(24, activation='relu')
        self.dense2 = layers.Dense(24, activation='relu')
        self.output_layer = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.output_layer(x)

# Instantiate models
generator = Generator()
discriminator = Discriminator()

# Optimizers
gen_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
disc_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# Loss functions
cross_entropy = tf.keras.losses.BinaryCrossentropy()

# Function to generate trajectories using the generator policy
def generate_trajectory(env, policy, max_steps=200):
    state = env.reset()
    states = []
    actions = []
    for _ in range(max_steps):
        state = state.reshape(1, -1)
        action_probs = policy(state)
        action = np.argmax(action_probs.numpy())
        next_state, reward, done, _ = env.step(action)
        states.append(state)
        actions.append(action)
        state = next_state
        if done:
            break
    states = np.array(states).reshape(-1, env.observation_space.shape[0])
    actions = np.array(actions).reshape(-1, 1)
    return states, actions

# Training loops (simplified)
def train_gail(env, generator, discriminator, gen_optimizer, disc_optimizer, expert_data, epochs=1000):
    expert_states, expert_actions = zip(*expert_data)
    expert_states = np.vstack(expert_states)
    expert_labels = np.ones((expert_states.shape[0], 1))

    for epoch in range(epochs):
        # Generate trajectories using the generator policy
        generated_states, generated_actions = generate_trajectory(env, generator)
        generated_labels = np.zeros((generated_states.shape[0], 1))

        # Combine expert and generated data
        all_states = np.vstack([expert_states, generated_states])
        all_labels = np.vstack([expert_labels, generated_labels])

        print(f'Epoch {epoch}')
        print(f'all_states shape: {all_states.shape}')
        print(f'all_labels shape: {all_labels.shape}')

        # Update discriminator
        with tf.GradientTape() as tape:
            pred_labels = discriminator(all_states)
            disc_loss = cross_entropy(all_labels, pred_labels)
            print(f'Disc Loss: {disc_loss.numpy()}')

        grads = tape.gradient(disc_loss, discriminator.trainable_variables)
        if not any(grad is None for grad in grads):
            disc_optimizer.apply_gradients(zip(grads, discriminator.trainable_variables))
        else:
            print("Discriminator gradients are None")

        # Update generator
        with tf.GradientTape() as tape:
            gen_pred_labels = discriminator(generated_states)
            gen_loss = cross_entropy(tf.ones_like(gen_pred_labels), gen_pred_labels)
            print(f'Gen Loss: {gen_loss.numpy()}')

        grads = tape.gradient(gen_loss, generator.trainable_variables)
        if not any(grad is None for grad in grads):
            gen_optimizer.apply_gradients(zip(grads, generator.trainable_variables))
        else:
            print("Generator gradients are None")

        if epoch % 100 == 0:
            print(f'Epoch: {epoch}, Discriminator Loss: {disc_loss.numpy()}, Generator Loss: {gen_loss.numpy()}')

# Example expert data (to be replaced with actual expert trajectories)
expert_data = [(np.random.random((1, 4)), np.random.randint(env.action_space.n)) for _ in range(100)]

# Format expert data correctly
expert_states = np.vstack([x[0] for x in expert_data])
expert_actions = np.array([x[1] for x in expert_data]).reshape(-1, 1)
expert_data = list(zip(expert_states, expert_actions))

# Train GAIL
train_gail(env, generator, discriminator, gen_optimizer, disc_optimizer, expert_data)

# Evaluate performance (simplified)
def evaluate_policy(env, policy):
    total_reward = 0
    state = env.reset()
    done = False
    while not done:
        state = state.reshape(1, -1)
        action = np.argmax(policy(state).numpy())
        state, reward, done, _ = env.step(action)
        total_reward += reward
    return total_reward

print(f'GAIL Policy Evaluation: {evaluate_policy(env, generator)}')
# Out:
# Streaming output truncated to the last 5000 lines.
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.10822189599275589
# Gen Loss: 1.9205527305603027
# Generator gradients are None
# Epoch 169
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.1518055498600006
# Gen Loss: 2.0285542011260986
# Generator gradients are None
# Epoch 170
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.10868223756551743
# Gen Loss: 2.3427393436431885
# Generator gradients are None
# Epoch 171
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.032340168952941895
# Gen Loss: 2.9699203968048096
# Generator gradients are None
# Epoch 172
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.03497376665472984
# Gen Loss: 2.8266515731811523
# Generator gradients are None
# Epoch 173
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.02982230670750141
# Gen Loss: 3.3773269653320312
# Generator gradients are None
# Epoch 174
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.10141859203577042
# Gen Loss: 2.017685651779175
# Generator gradients are None
# Epoch 175
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.1544269174337387
# Gen Loss: 2.0460567474365234
# Generator gradients are None
# Epoch 176
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.03072458505630493
# Gen Loss: 3.04850697517395
# Generator gradients are None
# Epoch 177
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.03143018111586571
# Gen Loss: 3.008650779724121
# Generator gradients are None
# Epoch 178
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.03229229152202606
# Gen Loss: 3.215179443359375
# Generator gradients are None
# Epoch 179
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.03402438387274742
# Gen Loss: 2.8269803524017334
# Generator gradients are None
# Epoch 180
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.03206109628081322
# Gen Loss: 3.221162796020508
# Generator gradients are None
# Epoch 181
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.14856232702732086
# Gen Loss: 2.093317985534668
# Generator gradients are None
# Epoch 182
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.029732532799243927
# Gen Loss: 3.347276210784912
# Generator gradients are None
# Epoch 183
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.1551351398229599
# Gen Loss: 1.8139792680740356
# Generator gradients are None
# Epoch 184
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.030739622190594673
# Gen Loss: 3.0139477252960205
# Generator gradients are None
# Epoch 185
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.04492071643471718
# Gen Loss: 2.9436771869659424
# Generator gradients are None
# Epoch 186
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.030666999518871307
# Gen Loss: 2.992506504058838
# Generator gradients are None
# Epoch 187
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.08021607249975204
# Gen Loss: 2.350151538848877
# Generator gradients are None
# Epoch 188
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.0776190459728241
# Gen Loss: 2.42000412940979
# Generator gradients are None
# Epoch 189
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.04604054614901543
# Gen Loss: 2.914708137512207
# Generator gradients are None
# Epoch 190
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.10146593302488327
# Gen Loss: 2.2423906326293945
# Generator gradients are None
# Epoch 191
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.08569760620594025
# Gen Loss: 2.225581407546997
# Generator gradients are None
# Epoch 192
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.030723266303539276
# Gen Loss: 2.7166357040405273
# Generator gradients are None
# Epoch 193
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.029481761157512665
# Gen Loss: 3.050175189971924
# Generator gradients are None
# Epoch 194
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.029132390394806862
# Gen Loss: 3.0809009075164795
# Generator gradients are None
# Epoch 195
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.03210289776325226
# Gen Loss: 2.6166515350341797
# Generator gradients are None
# Epoch 196
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.026923732832074165
# Gen Loss: 3.241539239883423
# Generator gradients are None
# Epoch 197
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0240805521607399
# Gen Loss: 3.754615068435669
# Generator gradients are None
# Epoch 198
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.041805632412433624
# Gen Loss: 3.0563735961914062
# Generator gradients are None
# Epoch 199
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.09866594523191452
# Gen Loss: 2.2957911491394043
# Generator gradients are None
# Epoch 200
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.023496169596910477
# Gen Loss: 3.7612502574920654
# Generator gradients are None
# Epoch: 200, Discriminator Loss: 0.023496169596910477, Generator Loss: 3.7612502574920654
# Epoch 201
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.026905829086899757
# Gen Loss: 3.466968059539795
# Generator gradients are None
# Epoch 202
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.02536148577928543
# Gen Loss: 3.5731232166290283
# Generator gradients are None
# Epoch 203
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.027056030929088593
# Gen Loss: 2.8568782806396484
# Generator gradients are None
# Epoch 204
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.023890646174550056
# Gen Loss: 3.6736133098602295
# Generator gradients are None
# Epoch 205
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.09426221996545792
# Gen Loss: 2.3196218013763428
# Generator gradients are None
# Epoch 206
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.02203221805393696
# Gen Loss: 3.835974931716919
# Generator gradients are None
# Epoch 207
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.024095209315419197
# Gen Loss: 3.3174777030944824
# Generator gradients are None
# Epoch 208
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.023500747978687286
# Gen Loss: 3.6566131114959717
# Generator gradients are None
# Epoch 209
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.023711759597063065
# Gen Loss: 3.5837414264678955
# Generator gradients are None
# Epoch 210
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.02483157068490982
# Gen Loss: 2.9152283668518066
# Generator gradients are None
# Epoch 211
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.023698361590504646
# Gen Loss: 3.530635356903076
# Generator gradients are None
# Epoch 212
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.02016305737197399
# Gen Loss: 3.8927276134490967
# Generator gradients are None
# Epoch 213
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.12424071133136749
# Gen Loss: 2.3437013626098633
# Generator gradients are None
# Epoch 214
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.030173052102327347
# Gen Loss: 2.45583438873291
# Generator gradients are None
# Epoch 215
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.02057960256934166
# Gen Loss: 3.780682325363159
# Generator gradients are None
# Epoch 216
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.023051174357533455
# Gen Loss: 3.524120807647705
# Generator gradients are None
# Epoch 217
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.01998046785593033
# Gen Loss: 3.821765899658203
# Generator gradients are None
# Epoch 218
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.027743494138121605
# Gen Loss: 2.5830588340759277
# Generator gradients are None
# Epoch 219
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.02173088863492012
# Gen Loss: 3.6431992053985596
# Generator gradients are None
# Epoch 220
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.0967930257320404
# Gen Loss: 2.2452313899993896
# Generator gradients are None
# Epoch 221
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.09042546153068542
# Gen Loss: 2.6182937622070312
# Generator gradients are None
# Epoch 222
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.018231051042675972
# Gen Loss: 3.9942450523376465
# Generator gradients are None
# Epoch 223
# all_states shape: (122, 4)
# all_labels shape: (122, 1)
# Disc Loss: 0.1518658697605133
# Gen Loss: 2.4582479000091553
# Generator gradients are None
# Epoch 224
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.046615373343229294
# Gen Loss: 2.8738808631896973
# Generator gradients are None
# Epoch 225
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.019977541640400887
# Gen Loss: 3.749443769454956
# Generator gradients are None
# Epoch 226
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.018929772078990936
# Gen Loss: 3.8934249877929688
# Generator gradients are None
# Epoch 227
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.022303331643342972
# Gen Loss: 2.9171817302703857
# Generator gradients are None
# Epoch 228
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.02100159414112568
# Gen Loss: 3.3189220428466797
# Generator gradients are None
# Epoch 229
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.02027304098010063
# Gen Loss: 3.710752487182617
# Generator gradients are None
# Epoch 230
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.09460046887397766
# Gen Loss: 2.749096632003784
# Generator gradients are None
# Epoch 231
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.1122555211186409
# Gen Loss: 2.187731981277466
# Generator gradients are None
# Epoch 232
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.020557478070259094
# Gen Loss: 3.0536961555480957
# Generator gradients are None
# Epoch 233
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.018459077924489975
# Gen Loss: 3.874974012374878
# Generator gradients are None
# Epoch 234
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.017774447798728943
# Gen Loss: 3.6702499389648438
# Generator gradients are None
# Epoch 235
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.020015642046928406
# Gen Loss: 3.647125244140625
# Generator gradients are None
# Epoch 236
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.017719075083732605
# Gen Loss: 3.946077346801758
# Generator gradients are None
# Epoch 237
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.019267866387963295
# Gen Loss: 3.1276676654815674
# Generator gradients are None
# Epoch 238
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.017050230875611305
# Gen Loss: 4.280765056610107
# Generator gradients are None
# Epoch 239
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.01896589994430542
# Gen Loss: 3.141768455505371
# Generator gradients are None
# Epoch 240
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.019140711054205894
# Gen Loss: 3.097811222076416
# Generator gradients are None
# Epoch 241
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.01695426180958748
# Gen Loss: 3.690680503845215
# Generator gradients are None
# Epoch 242
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.08207345753908157
# Gen Loss: 2.369256019592285
# Generator gradients are None
# Epoch 243
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.01828274317085743
# Gen Loss: 3.788818359375
# Generator gradients are None
# Epoch 244
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.017354950308799744
# Gen Loss: 3.5812008380889893
# Generator gradients are None
# Epoch 245
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.016921356320381165
# Gen Loss: 3.93620228767395
# Generator gradients are None
# Epoch 246
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.016632281243801117
# Gen Loss: 3.9526278972625732
# Generator gradients are None
# Epoch 247
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.09672512114048004
# Gen Loss: 2.5980582237243652
# Generator gradients are None
# Epoch 248
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.10125624388456345
# Gen Loss: 2.509129524230957
# Generator gradients are None
# Epoch 249
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.01686217077076435
# Gen Loss: 3.878653049468994
# Generator gradients are None
# Epoch 250
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.09966401010751724
# Gen Loss: 2.525031328201294
# Generator gradients are None
# Epoch 251
# all_states shape: (122, 4)
# all_labels shape: (122, 1)
# Disc Loss: 0.10660113394260406
# Gen Loss: 1.9327739477157593
# Generator gradients are None
# Epoch 252
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.015975311398506165
# Gen Loss: 4.031535625457764
# Generator gradients are None
# Epoch 253
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.021699683740735054
# Gen Loss: 3.807807683944702
# Generator gradients are None
# Epoch 254
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.09600725769996643
# Gen Loss: 2.2760777473449707
# Generator gradients are None
# Epoch 255
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.015173076651990414
# Gen Loss: 4.172399044036865
# Generator gradients are None
# Epoch 256
# all_states shape: (113, 4)
# all_labels shape: (113, 1)
# Disc Loss: 0.02438514120876789
# Gen Loss: 3.8673863410949707
# Generator gradients are None
# Epoch 257
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.016120299696922302
# Gen Loss: 3.990943431854248
# Generator gradients are None
# Epoch 258
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.047236207872629166
# Gen Loss: 2.8936398029327393
# Generator gradients are None
# Epoch 259
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.014585468918085098
# Gen Loss: 4.244065284729004
# Generator gradients are None
# Epoch 260
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.017143074423074722
# Gen Loss: 3.8363754749298096
# Generator gradients are None
# Epoch 261
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.017422916367650032
# Gen Loss: 3.4447667598724365
# Generator gradients are None
# Epoch 262
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.014168777503073215
# Gen Loss: 4.363476276397705
# Generator gradients are None
# Epoch 263
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.01320656668394804
# Gen Loss: 4.860356330871582
# Generator gradients are None
# Epoch 264
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.015130792744457722
# Gen Loss: 3.5178394317626953
# Generator gradients are None
# Epoch 265
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.01751146838068962
# Gen Loss: 3.3616979122161865
# Generator gradients are None
# Epoch 266
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.015735844150185585
# Gen Loss: 3.885327100753784
# Generator gradients are None
# Epoch 267
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.014290884137153625
# Gen Loss: 3.8495237827301025
# Generator gradients are None
# Epoch 268
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.015651123598217964
# Gen Loss: 3.878594160079956
# Generator gradients are None
# Epoch 269
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.06480778753757477
# Gen Loss: 2.565664291381836
# Generator gradients are None
# Epoch 270
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.013000604696571827
# Gen Loss: 4.341281890869141
# Generator gradients are None
# Epoch 271
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.01268150843679905
# Gen Loss: 4.4477362632751465
# Generator gradients are None
# Epoch 272
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.014874542132019997
# Gen Loss: 3.8884825706481934
# Generator gradients are None
# Epoch 273
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.012910237535834312
# Gen Loss: 4.297721862792969
# Generator gradients are None
# Epoch 274
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.0707932636141777
# Gen Loss: 2.974327564239502
# Generator gradients are None
# Epoch 275
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.012138089165091515
# Gen Loss: 4.467899799346924
# Generator gradients are None
# Epoch 276
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.015160864219069481
# Gen Loss: 3.488445281982422
# Generator gradients are None
# Epoch 277
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.07006705552339554
# Gen Loss: 2.8777129650115967
# Generator gradients are None
# Epoch 278
# all_states shape: (120, 4)
# all_labels shape: (120, 1)
# Disc Loss: 0.08746810257434845
# Gen Loss: 2.0715041160583496
# Generator gradients are None
# Epoch 279
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.014827222563326359
# Gen Loss: 3.457179307937622
# Generator gradients are None
# Epoch 280
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.01369042880833149
# Gen Loss: 3.672865629196167
# Generator gradients are None
# Epoch 281
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.01318439096212387
# Gen Loss: 4.033600807189941
# Generator gradients are None
# Epoch 282
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.014370746910572052
# Gen Loss: 3.5235581398010254
# Generator gradients are None
# Epoch 283
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.011592237278819084
# Gen Loss: 4.440518379211426
# Generator gradients are None
# Epoch 284
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.01306416280567646
# Gen Loss: 3.755620241165161
# Generator gradients are None
# Epoch 285
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.01546353567391634
# Gen Loss: 3.058074951171875
# Generator gradients are None
# Epoch 286
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.01262859907001257
# Gen Loss: 4.379741668701172
# Generator gradients are None
# Epoch 287
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.012423768639564514
# Gen Loss: 4.08664083480835
# Generator gradients are None
# Epoch 288
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.04149435833096504
# Gen Loss: 3.5260307788848877
# Generator gradients are None
# Epoch 289
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.015699423849582672
# Gen Loss: 2.989583969116211
# Generator gradients are None
# Epoch 290
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.014461599290370941
# Gen Loss: 3.396406888961792
# Generator gradients are None
# Epoch 291
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.026271361857652664
# Gen Loss: 3.3350584506988525
# Generator gradients are None
# Epoch 292
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.010990254580974579
# Gen Loss: 4.467328071594238
# Generator gradients are None
# Epoch 293
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.011120409704744816
# Gen Loss: 4.6325531005859375
# Generator gradients are None
# Epoch 294
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.014711437746882439
# Gen Loss: 3.0705440044403076
# Generator gradients are None
# Epoch 295
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.08023451268672943
# Gen Loss: 2.2686824798583984
# Generator gradients are None
# Epoch 296
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.012572258710861206
# Gen Loss: 3.6279313564300537
# Generator gradients are None
# Epoch 297
# all_states shape: (124, 4)
# all_labels shape: (124, 1)
# Disc Loss: 0.09360936284065247
# Gen Loss: 1.9769344329833984
# Generator gradients are None
# Epoch 298
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.014343238435685635
# Gen Loss: 3.3664586544036865
# Generator gradients are None
# Epoch 299
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.012364804744720459
# Gen Loss: 3.994988203048706
# Generator gradients are None
# Epoch 300
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.02007920853793621
# Gen Loss: 3.502575635910034
# Generator gradients are None
# Epoch: 300, Discriminator Loss: 0.02007920853793621, Generator Loss: 3.502575635910034
# Epoch 301
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.012323121540248394
# Gen Loss: 4.004878997802734
# Generator gradients are None
# Epoch 302
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.011618932709097862
# Gen Loss: 3.890422821044922
# Generator gradients are None
# Epoch 303
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.011410652659833431
# Gen Loss: 4.212810516357422
# Generator gradients are None
# Epoch 304
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.011614035815000534
# Gen Loss: 3.895549774169922
# Generator gradients are None
# Epoch 305
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.010107975453138351
# Gen Loss: 4.674712657928467
# Generator gradients are None
# Epoch 306
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.053611356765031815
# Gen Loss: 2.623544931411743
# Generator gradients are None
# Epoch 307
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.010097930207848549
# Gen Loss: 4.577813148498535
# Generator gradients are None
# Epoch 308
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.013143702410161495
# Gen Loss: 3.284210205078125
# Generator gradients are None
# Epoch 309
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.01112173032015562
# Gen Loss: 3.9915144443511963
# Generator gradients are None
# Epoch 310
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.010950816795229912
# Gen Loss: 4.28912353515625
# Generator gradients are None
# Epoch 311
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.010313797742128372
# Gen Loss: 4.490694522857666
# Generator gradients are None
# Epoch 312
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.00976557470858097
# Gen Loss: 4.626911163330078
# Generator gradients are None
# Epoch 313
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.032856643199920654
# Gen Loss: 3.8362085819244385
# Generator gradients are None
# Epoch 314
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.010799191892147064
# Gen Loss: 4.256333827972412
# Generator gradients are None
# Epoch 315
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.010298969224095345
# Gen Loss: 4.109142303466797
# Generator gradients are None
# Epoch 316
# all_states shape: (113, 4)
# all_labels shape: (113, 1)
# Disc Loss: 0.013386312872171402
# Gen Loss: 4.481073379516602
# Generator gradients are None
# Epoch 317
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.01216439064592123
# Gen Loss: 3.3459975719451904
# Generator gradients are None
# Epoch 318
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.06043929234147072
# Gen Loss: 2.9343647956848145
# Generator gradients are None
# Epoch 319
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.019010446965694427
# Gen Loss: 4.036494255065918
# Generator gradients are None
# Epoch 320
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.05199357867240906
# Gen Loss: 3.2099790573120117
# Generator gradients are None
# Epoch 321
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.010416802018880844
# Gen Loss: 3.6263904571533203
# Generator gradients are None
# Epoch 322
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.05513828992843628
# Gen Loss: 3.058577060699463
# Generator gradients are None
# Epoch 323
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.0269701536744833
# Gen Loss: 3.2715725898742676
# Generator gradients are None
# Epoch 324
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.009900455363094807
# Gen Loss: 3.9604687690734863
# Generator gradients are None
# Epoch 325
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.028335390612483025
# Gen Loss: 3.9465088844299316
# Generator gradients are None
# Epoch 326
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.010211993008852005
# Gen Loss: 3.581998586654663
# Generator gradients are None
# Epoch 327
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.00982807856053114
# Gen Loss: 3.723029613494873
# Generator gradients are None
# Epoch 328
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.012719417922198772
# Gen Loss: 4.054684162139893
# Generator gradients are None
# Epoch 329
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.008738151751458645
# Gen Loss: 4.601069450378418
# Generator gradients are None
# Epoch 330
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.008374173194169998
# Gen Loss: 4.755080223083496
# Generator gradients are None
# Epoch 331
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.007975230924785137
# Gen Loss: 4.929102420806885
# Generator gradients are None
# Epoch 332
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.009305707179009914
# Gen Loss: 3.728031635284424
# Generator gradients are None
# Epoch 333
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.008351699449121952
# Gen Loss: 4.5623674392700195
# Generator gradients are None
# Epoch 334
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.008127101697027683
# Gen Loss: 4.675806522369385
# Generator gradients are None
# Epoch 335
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.017841652035713196
# Gen Loss: 3.8463878631591797
# Generator gradients are None
# Epoch 336
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.007869814522564411
# Gen Loss: 4.684144020080566
# Generator gradients are None
# Epoch 337
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.027568429708480835
# Gen Loss: 3.739675760269165
# Generator gradients are None
# Epoch 338
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.009496613405644894
# Gen Loss: 3.710261344909668
# Generator gradients are None
# Epoch 339
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.008458580821752548
# Gen Loss: 4.280052185058594
# Generator gradients are None
# Epoch 340
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.009180433116853237
# Gen Loss: 4.062891960144043
# Generator gradients are None
# Epoch 341
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0086043206974864
# Gen Loss: 3.87646746635437
# Generator gradients are None
# Epoch 342
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.013925234787166119
# Gen Loss: 3.610417604446411
# Generator gradients are None
# Epoch 343
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.011612175032496452
# Gen Loss: 4.223743915557861
# Generator gradients are None
# Epoch 344
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.008644700050354004
# Gen Loss: 3.820448637008667
# Generator gradients are None
# Epoch 345
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.01432016957551241
# Gen Loss: 3.5695197582244873
# Generator gradients are None
# Epoch 346
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.007445685565471649
# Gen Loss: 4.500977993011475
# Generator gradients are None
# Epoch 347
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.008739019744098186
# Gen Loss: 4.039503574371338
# Generator gradients are None
# Epoch 348
# all_states shape: (124, 4)
# all_labels shape: (124, 1)
# Disc Loss: 0.040956076234579086
# Gen Loss: 2.5175857543945312
# Generator gradients are None
# Epoch 349
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.007415479980409145
# Gen Loss: 4.496127605438232
# Generator gradients are None
# Epoch 350
# all_states shape: (126, 4)
# all_labels shape: (126, 1)
# Disc Loss: 0.0667378231883049
# Gen Loss: 2.1172382831573486
# Generator gradients are None
# Epoch 351
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.020223254337906837
# Gen Loss: 3.43570876121521
# Generator gradients are None
# Epoch 352
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.007092918734997511
# Gen Loss: 4.66157865524292
# Generator gradients are None
# Epoch 353
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.007849743589758873
# Gen Loss: 4.342205047607422
# Generator gradients are None
# Epoch 354
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.009845578111708164
# Gen Loss: 3.5445775985717773
# Generator gradients are None
# Epoch 355
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.03639906644821167
# Gen Loss: 3.3974297046661377
# Generator gradients are None
# Epoch 356
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.016983019188046455
# Gen Loss: 3.775737762451172
# Generator gradients are None
# Epoch 357
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.007857725955545902
# Gen Loss: 4.120248794555664
# Generator gradients are None
# Epoch 358
# all_states shape: (120, 4)
# all_labels shape: (120, 1)
# Disc Loss: 0.022491829469799995
# Gen Loss: 3.27197265625
# Generator gradients are None
# Epoch 359
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.008274337276816368
# Gen Loss: 3.9582087993621826
# Generator gradients are None
# Epoch 360
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.00816507451236248
# Gen Loss: 4.000339984893799
# Generator gradients are None
# Epoch 361
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.007642215583473444
# Gen Loss: 4.196375846862793
# Generator gradients are None
# Epoch 362
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0063200704753398895
# Gen Loss: 5.414882659912109
# Generator gradients are None
# Epoch 363
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.007831715978682041
# Gen Loss: 4.333176612854004
# Generator gradients are None
# Epoch 364
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.00725820567458868
# Gen Loss: 4.600056171417236
# Generator gradients are None
# Epoch 365
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.00651985639706254
# Gen Loss: 5.037511348724365
# Generator gradients are None
# Epoch 366
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.007536082994192839
# Gen Loss: 4.4127326011657715
# Generator gradients are None
# Epoch 367
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0065629552118480206
# Gen Loss: 4.9467926025390625
# Generator gradients are None
# Epoch 368
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.00882467720657587
# Gen Loss: 3.4425387382507324
# Generator gradients are None
# Epoch 369
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.007404166739434004
# Gen Loss: 4.120291233062744
# Generator gradients are None
# Epoch 370
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.006910652853548527
# Gen Loss: 4.589815616607666
# Generator gradients are None
# Epoch 371
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.007819844409823418
# Gen Loss: 3.930692434310913
# Generator gradients are None
# Epoch 372
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.005901726894080639
# Gen Loss: 5.338111400604248
# Generator gradients are None
# Epoch 373
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.02278943918645382
# Gen Loss: 3.51552677154541
# Generator gradients are None
# Epoch 374
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.008255206048488617
# Gen Loss: 3.7443058490753174
# Generator gradients are None
# Epoch 375
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.008959722705185413
# Gen Loss: 3.3444981575012207
# Generator gradients are None
# Epoch 376
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.006478238385170698
# Gen Loss: 4.364796161651611
# Generator gradients are None
# Epoch 377
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.007050808053463697
# Gen Loss: 4.044707298278809
# Generator gradients are None
# Epoch 378
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.005968133453279734
# Gen Loss: 4.9501953125
# Generator gradients are None
# Epoch 379
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.005448759533464909
# Gen Loss: 5.583291530609131
# Generator gradients are None
# Epoch 380
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0058793858624994755
# Gen Loss: 4.904350280761719
# Generator gradients are None
# Epoch 381
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.008725537918508053
# Gen Loss: 4.2489013671875
# Generator gradients are None
# Epoch 382
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.019391696900129318
# Gen Loss: 3.3764469623565674
# Generator gradients are None
# Epoch 383
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.006537360139191151
# Gen Loss: 4.133474349975586
# Generator gradients are None
# Epoch 384
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.005301906261593103
# Gen Loss: 5.310335636138916
# Generator gradients are None
# Epoch 385
# all_states shape: (122, 4)
# all_labels shape: (122, 1)
# Disc Loss: 0.034726835787296295
# Gen Loss: 3.969813346862793
# Generator gradients are None
# Epoch 386
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.039272431284189224
# Gen Loss: 2.7799839973449707
# Generator gradients are None
# Epoch 387
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.005285778548568487
# Gen Loss: 5.370673656463623
# Generator gradients are None
# Epoch 388
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0055532450787723064
# Gen Loss: 4.8974151611328125
# Generator gradients are None
# Epoch 389
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.006824776995927095
# Gen Loss: 3.7166848182678223
# Generator gradients are None
# Epoch 390
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0061330487951636314
# Gen Loss: 3.978567600250244
# Generator gradients are None
# Epoch 391
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.007240126840770245
# Gen Loss: 3.7840147018432617
# Generator gradients are None
# Epoch 392
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.005855300929397345
# Gen Loss: 4.342691421508789
# Generator gradients are None
# Epoch 393
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.006168265361338854
# Gen Loss: 4.1613922119140625
# Generator gradients are None
# Epoch 394
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.006217367481440306
# Gen Loss: 3.8915114402770996
# Generator gradients are None
# Epoch 395
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.006269988138228655
# Gen Loss: 4.355067253112793
# Generator gradients are None
# Epoch 396
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.004721920005977154
# Gen Loss: 5.6981353759765625
# Generator gradients are None
# Epoch 397
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004692771006375551
# Gen Loss: 5.485033988952637
# Generator gradients are None
# Epoch 398
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0060134343802928925
# Gen Loss: 3.9501171112060547
# Generator gradients are None
# Epoch 399
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.005144755821675062
# Gen Loss: 4.887700080871582
# Generator gradients are None
# Epoch 400
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004833335988223553
# Gen Loss: 5.128911018371582
# Generator gradients are None
# Epoch: 400, Discriminator Loss: 0.004833335988223553, Generator Loss: 5.128911018371582
# Epoch 401
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.005157802253961563
# Gen Loss: 4.516435623168945
# Generator gradients are None
# Epoch 402
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.01340052392333746
# Gen Loss: 3.520800828933716
# Generator gradients are None
# Epoch 403
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.00511980801820755
# Gen Loss: 4.757960319519043
# Generator gradients are None
# Epoch 404
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.005048638675361872
# Gen Loss: 4.878261566162109
# Generator gradients are None
# Epoch 405
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.005391581449657679
# Gen Loss: 4.324071407318115
# Generator gradients are None
# Epoch 406
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004282367881387472
# Gen Loss: 5.5764312744140625
# Generator gradients are None
# Epoch 407
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004923276603221893
# Gen Loss: 4.566991806030273
# Generator gradients are None
# Epoch 408
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.02246776968240738
# Gen Loss: 3.2477145195007324
# Generator gradients are None
# Epoch 409
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.017897170037031174
# Gen Loss: 3.7361676692962646
# Generator gradients are None
# Epoch 410
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.006379379890859127
# Gen Loss: 3.6181817054748535
# Generator gradients are None
# Epoch 411
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004811200313270092
# Gen Loss: 4.906520366668701
# Generator gradients are None
# Epoch 412
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.006741697434335947
# Gen Loss: 3.6904094219207764
# Generator gradients are None
# Epoch 413
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0051622395403683186
# Gen Loss: 4.278650283813477
# Generator gradients are None
# Epoch 414
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004495400004088879
# Gen Loss: 5.0421881675720215
# Generator gradients are None
# Epoch 415
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.00822683796286583
# Gen Loss: 3.147141933441162
# Generator gradients are None
# Epoch 416
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004753445275127888
# Gen Loss: 4.573267936706543
# Generator gradients are None
# Epoch 417
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.007230360526591539
# Gen Loss: 3.3567163944244385
# Generator gradients are None
# Epoch 418
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.007429234683513641
# Gen Loss: 4.1951069831848145
# Generator gradients are None
# Epoch 419
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004121572244912386
# Gen Loss: 5.352973937988281
# Generator gradients are None
# Epoch 420
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.013502768240869045
# Gen Loss: 3.595141887664795
# Generator gradients are None
# Epoch 421
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004921680316329002
# Gen Loss: 4.427224159240723
# Generator gradients are None
# Epoch 422
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004451180342584848
# Gen Loss: 4.960790157318115
# Generator gradients are None
# Epoch 423
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004526579286903143
# Gen Loss: 4.659966945648193
# Generator gradients are None
# Epoch 424
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0073081511072814465
# Gen Loss: 3.315826892852783
# Generator gradients are None
# Epoch 425
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004791154991835356
# Gen Loss: 4.468486309051514
# Generator gradients are None
# Epoch 426
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.005508081521838903
# Gen Loss: 4.122264862060547
# Generator gradients are None
# Epoch 427
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004875854589045048
# Gen Loss: 4.445708751678467
# Generator gradients are None
# Epoch 428
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.003719993634149432
# Gen Loss: 5.9778666496276855
# Generator gradients are None
# Epoch 429
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.01047877874225378
# Gen Loss: 3.8505027294158936
# Generator gradients are None
# Epoch 430
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004250499419867992
# Gen Loss: 5.147037029266357
# Generator gradients are None
# Epoch 431
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.004164958838373423
# Gen Loss: 5.071628093719482
# Generator gradients are None
# Epoch 432
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.018679948523640633
# Gen Loss: 3.677417516708374
# Generator gradients are None
# Epoch 433
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004285596311092377
# Gen Loss: 4.711999416351318
# Generator gradients are None
# Epoch 434
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0043313163332641125
# Gen Loss: 4.972917079925537
# Generator gradients are None
# Epoch 435
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0038717358838766813
# Gen Loss: 5.356703758239746
# Generator gradients are None
# Epoch 436
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0036442596465349197
# Gen Loss: 5.71830415725708
# Generator gradients are None
# Epoch 437
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.004412781912833452
# Gen Loss: 4.332645893096924
# Generator gradients are None
# Epoch 438
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.006984780076891184
# Gen Loss: 4.556110858917236
# Generator gradients are None
# Epoch 439
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0042554582469165325
# Gen Loss: 4.925492763519287
# Generator gradients are None
# Epoch 440
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.024352479726076126
# Gen Loss: 3.8238513469696045
# Generator gradients are None
# Epoch 441
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.0037767672911286354
# Gen Loss: 5.5858540534973145
# Generator gradients are None
# Epoch 442
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.004904088098555803
# Gen Loss: 4.018777847290039
# Generator gradients are None
# Epoch 443
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0038215445820242167
# Gen Loss: 4.94338321685791
# Generator gradients are None
# Epoch 444
# all_states shape: (122, 4)
# all_labels shape: (122, 1)
# Disc Loss: 0.01781742088496685
# Gen Loss: 3.3022139072418213
# Generator gradients are None
# Epoch 445
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.004720132332295179
# Gen Loss: 4.072442054748535
# Generator gradients are None
# Epoch 446
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.025915004312992096
# Gen Loss: 3.553149461746216
# Generator gradients are None
# Epoch 447
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.004817184526473284
# Gen Loss: 3.994391918182373
# Generator gradients are None
# Epoch 448
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.0035952450707554817
# Gen Loss: 5.740026950836182
# Generator gradients are None
# Epoch 449
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.024566765874624252
# Gen Loss: 3.1038012504577637
# Generator gradients are None
# Epoch 450
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0034779885318130255
# Gen Loss: 5.704537391662598
# Generator gradients are None
# Epoch 451
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004353080410510302
# Gen Loss: 4.446900844573975
# Generator gradients are None
# Epoch 452
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.004357895348221064
# Gen Loss: 5.545530319213867
# Generator gradients are None
# Epoch 453
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.013819129206240177
# Gen Loss: 4.107102870941162
# Generator gradients are None
# Epoch 454
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.008948477916419506
# Gen Loss: 4.229851722717285
# Generator gradients are None
# Epoch 455
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.003521718317642808
# Gen Loss: 5.369618892669678
# Generator gradients are None
# Epoch 456
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.004405163694173098
# Gen Loss: 4.25052547454834
# Generator gradients are None
# Epoch 457
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0036829060409218073
# Gen Loss: 5.326796054840088
# Generator gradients are None
# Epoch 458
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.00356470444239676
# Gen Loss: 5.440230369567871
# Generator gradients are None
# Epoch 459
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004510477185249329
# Gen Loss: 4.346652030944824
# Generator gradients are None
# Epoch 460
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0032425036188215017
# Gen Loss: 5.918392181396484
# Generator gradients are None
# Epoch 461
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0038418688345700502
# Gen Loss: 5.1097092628479
# Generator gradients are None
# Epoch 462
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0037959350738674402
# Gen Loss: 5.067529678344727
# Generator gradients are None
# Epoch 463
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.003741589142009616
# Gen Loss: 5.116492748260498
# Generator gradients are None
# Epoch 464
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.003558668540790677
# Gen Loss: 5.036653518676758
# Generator gradients are None
# Epoch 465
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0036535640247166157
# Gen Loss: 5.1272382736206055
# Generator gradients are None
# Epoch 466
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0035404611844569445
# Gen Loss: 5.025815963745117
# Generator gradients are None
# Epoch 467
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0037188592832535505
# Gen Loss: 4.790266036987305
# Generator gradients are None
# Epoch 468
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.004108078312128782
# Gen Loss: 4.505443096160889
# Generator gradients are None
# Epoch 469
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0034890915267169476
# Gen Loss: 5.321813106536865
# Generator gradients are None
# Epoch 470
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0037936153821647167
# Gen Loss: 4.9663848876953125
# Generator gradients are None
# Epoch 471
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0037981094792485237
# Gen Loss: 4.6508893966674805
# Generator gradients are None
# Epoch 472
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0032837637700140476
# Gen Loss: 5.371568202972412
# Generator gradients are None
# Epoch 473
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.004440086428076029
# Gen Loss: 3.9860029220581055
# Generator gradients are None
# Epoch 474
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0038621718995273113
# Gen Loss: 4.288210391998291
# Generator gradients are None
# Epoch 475
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.00293551292270422
# Gen Loss: 6.100466728210449
# Generator gradients are None
# Epoch 476
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.002972448943182826
# Gen Loss: 5.719676971435547
# Generator gradients are None
# Epoch 477
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0034614938776940107
# Gen Loss: 4.8442511558532715
# Generator gradients are None
# Epoch 478
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.02095462940633297
# Gen Loss: 3.5398733615875244
# Generator gradients are None
# Epoch 479
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0038036161568015814
# ...
# Generator gradients are None
# Epoch 897
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0007398874731734395
# Gen Loss: 6.3704328536987305
# Generator gradients are None
# Epoch 898
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.000654058821965009
# Gen Loss: 7.231325626373291
# Generator gradients are None
# Epoch 899
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.000880345469340682
# Gen Loss: 5.755070686340332
# Generator gradients are None
# Epoch 900
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.000620878825429827
# Gen Loss: 7.60400390625
# Generator gradients are None
# Epoch: 900, Discriminator Loss: 0.000620878825429827, Generator Loss: 7.60400390625
# Epoch 901
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.000714972207788378
# Gen Loss: 6.848808288574219
# Generator gradients are None
# Epoch 902
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006361884297803044
# Gen Loss: 7.395497798919678
# Generator gradients are None
# Epoch 903
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0007326705381274223
# Gen Loss: 6.347569465637207
# Generator gradients are None
# Epoch 904
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006206120015121996
# Gen Loss: 7.538551330566406
# Generator gradients are None
# Epoch 905
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006824239389970899
# Gen Loss: 6.893193244934082
# Generator gradients are None
# Epoch 906
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0007011485868133605
# Gen Loss: 6.833834648132324
# Generator gradients are None
# Epoch 907
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006352908676490188
# Gen Loss: 7.274511814117432
# Generator gradients are None
# Epoch 908
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.0030322950333356857
# Gen Loss: 5.6295485496521
# Generator gradients are None
# Epoch 909
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0007657247479073703
# Gen Loss: 6.132359504699707
# Generator gradients are None
# Epoch 910
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.0005813367897644639
# Gen Loss: 8.140851974487305
# Generator gradients are None
# Epoch 911
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006828309269621968
# Gen Loss: 6.59991979598999
# Generator gradients are None
# Epoch 912
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0010519028874114156
# Gen Loss: 5.094852447509766
# Generator gradients are None
# Epoch 913
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.0010962651576846838
# Gen Loss: 5.834615230560303
# Generator gradients are None
# Epoch 914
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006163688376545906
# Gen Loss: 7.279791355133057
# Generator gradients are None
# Epoch 915
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0008893838967196643
# Gen Loss: 5.5794148445129395
# Generator gradients are None
# Epoch 916
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0007485058740712702
# Gen Loss: 6.109891414642334
# Generator gradients are None
# Epoch 917
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006611822172999382
# Gen Loss: 6.885705471038818
# Generator gradients are None
# Epoch 918
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0007193361525423825
# Gen Loss: 6.034564018249512
# Generator gradients are None
# Epoch 919
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006877256673760712
# Gen Loss: 6.62039852142334
# Generator gradients are None
# Epoch 920
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.0018912561936303973
# Gen Loss: 6.123238563537598
# Generator gradients are None
# Epoch 921
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006320190150290728
# Gen Loss: 6.812236309051514
# Generator gradients are None
# Epoch 922
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006348282913677394
# Gen Loss: 6.8907790184021
# Generator gradients are None
# Epoch 923
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.0023127051535993814
# Gen Loss: 5.371151924133301
# Generator gradients are None
# Epoch 924
# all_states shape: (112, 4)
# all_labels shape: (112, 1)
# Disc Loss: 0.0007320010336115956
# Gen Loss: 7.104094982147217
# Generator gradients are None
# Epoch 925
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005597035051323473
# Gen Loss: 7.705018520355225
# Generator gradients are None
# Epoch 926
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006397218676283956
# Gen Loss: 6.573132514953613
# Generator gradients are None
# Epoch 927
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006904579931870103
# Gen Loss: 6.551266670227051
# Generator gradients are None
# Epoch 928
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0009076489368453622
# Gen Loss: 5.5432281494140625
# Generator gradients are None
# Epoch 929
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.002074688673019409
# Gen Loss: 5.147068977355957
# Generator gradients are None
# Epoch 930
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.0023587332107126713
# Gen Loss: 5.069269180297852
# Generator gradients are None
# Epoch 931
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.002936525736004114
# Gen Loss: 4.776588439941406
# Generator gradients are None
# Epoch 932
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005486729205586016
# Gen Loss: 7.836617946624756
# Generator gradients are None
# Epoch 933
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006246633711270988
# Gen Loss: 6.8003363609313965
# Generator gradients are None
# Epoch 934
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0007455825689248741
# Gen Loss: 6.281508922576904
# Generator gradients are None
# Epoch 935
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006767130689695477
# Gen Loss: 6.6421661376953125
# Generator gradients are None
# Epoch 936
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006370238843373954
# Gen Loss: 6.8109331130981445
# Generator gradients are None
# Epoch 937
# all_states shape: (114, 4)
# all_labels shape: (114, 1)
# Disc Loss: 0.0018320577219128609
# Gen Loss: 5.304903507232666
# Generator gradients are None
# Epoch 938
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.002479649381712079
# Gen Loss: 5.195452690124512
# Generator gradients are None
# Epoch 939
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005823135143145919
# Gen Loss: 7.2714643478393555
# Generator gradients are None
# Epoch 940
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0009725296404212713
# Gen Loss: 5.167911529541016
# Generator gradients are None
# Epoch 941
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0007185022695921361
# Gen Loss: 5.905872344970703
# Generator gradients are None
# Epoch 942
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006130239344201982
# Gen Loss: 7.028975009918213
# Generator gradients are None
# Epoch 943
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0007728317868895829
# Gen Loss: 5.919197082519531
# Generator gradients are None
# Epoch 944
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006399989943020046
# Gen Loss: 6.72573709487915
# Generator gradients are None
# Epoch 945
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.000565985799767077
# Gen Loss: 7.499397277832031
# Generator gradients are None
# Epoch 946
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005405160482041538
# Gen Loss: 7.848370552062988
# Generator gradients are None
# Epoch 947
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0007235362427309155
# Gen Loss: 6.045294761657715
# Generator gradients are None
# Epoch 948
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006296210340224206
# Gen Loss: 6.58884334564209
# Generator gradients are None
# Epoch 949
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.000593690958339721
# Gen Loss: 7.0657196044921875
# Generator gradients are None
# Epoch 950
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0006797657115384936
# Gen Loss: 6.504861354827881
# Generator gradients are None
# Epoch 951
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.001676026382483542
# Gen Loss: 6.940199851989746
# Generator gradients are None
# Epoch 952
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006856382242403924
# Gen Loss: 6.130414962768555
# Generator gradients are None
# Epoch 953
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0008521931595169008
# Gen Loss: 5.608346939086914
# Generator gradients are None
# Epoch 954
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0006766564911231399
# Gen Loss: 6.001954078674316
# Generator gradients are None
# Epoch 955
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.001949177822098136
# Gen Loss: 4.148725509643555
# Generator gradients are None
# Epoch 956
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0009024288738146424
# Gen Loss: 5.313899040222168
# Generator gradients are None
# Epoch 957
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005192155949771404
# Gen Loss: 7.906852722167969
# Generator gradients are None
# Epoch 958
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0006637286860495806
# Gen Loss: 6.118104934692383
# Generator gradients are None
# Epoch 959
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006381379207596183
# Gen Loss: 6.427600383758545
# Generator gradients are None
# Epoch 960
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0007830201066099107
# Gen Loss: 5.618234157562256
# Generator gradients are None
# Epoch 961
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006065008346922696
# Gen Loss: 6.672264099121094
# Generator gradients are None
# Epoch 962
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0006001066067256033
# Gen Loss: 6.541419506072998
# Generator gradients are None
# Epoch 963
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.000657861412037164
# Gen Loss: 6.1477155685424805
# Generator gradients are None
# Epoch 964
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005369944265112281
# Gen Loss: 7.46811056137085
# Generator gradients are None
# Epoch 965
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0005533749354071915
# Gen Loss: 7.195070266723633
# Generator gradients are None
# Epoch 966
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.000580119900405407
# Gen Loss: 6.950498580932617
# Generator gradients are None
# Epoch 967
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.00376519956625998
# Gen Loss: 4.867887496948242
# Generator gradients are None
# Epoch 968
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0008004544652067125
# Gen Loss: 5.614770889282227
# Generator gradients are None
# Epoch 969
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005145777831785381
# Gen Loss: 7.841862678527832
# Generator gradients are None
# Epoch 970
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.0010086424881592393
# Gen Loss: 7.845019340515137
# Generator gradients are None
# Epoch 971
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.002335679018869996
# Gen Loss: 5.285275459289551
# Generator gradients are None
# Epoch 972
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0005461054970510304
# Gen Loss: 7.093696594238281
# Generator gradients are None
# Epoch 973
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0007674555527046323
# Gen Loss: 5.6803178787231445
# Generator gradients are None
# Epoch 974
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.001243339036591351
# Gen Loss: 4.783882141113281
# Generator gradients are None
# Epoch 975
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006265141419135034
# Gen Loss: 6.440532684326172
# Generator gradients are None
# Epoch 976
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.0018078890861943364
# Gen Loss: 5.778778076171875
# Generator gradients are None
# Epoch 977
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0006519824382849038
# Gen Loss: 6.062856674194336
# Generator gradients are None
# Epoch 978
# all_states shape: (132, 4)
# all_labels shape: (132, 1)
# Disc Loss: 0.007367113139480352
# Gen Loss: 4.11832857131958
# Generator gradients are None
# Epoch 979
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0004893820150755346
# Gen Loss: 8.245503425598145
# Generator gradients are None
# Epoch 980
# all_states shape: (118, 4)
# all_labels shape: (118, 1)
# Disc Loss: 0.0023578309919685125
# Gen Loss: 5.633792400360107
# Generator gradients are None
# Epoch 981
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0007608715677633882
# Gen Loss: 5.926309585571289
# Generator gradients are None
# Epoch 982
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0005795620963908732
# Gen Loss: 6.809636116027832
# Generator gradients are None
# Epoch 983
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005532157956622541
# Gen Loss: 7.3968305587768555
# Generator gradients are None
# Epoch 984
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0005733698490075767
# Gen Loss: 6.929658889770508
# Generator gradients are None
# Epoch 985
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0007687342003919184
# Gen Loss: 5.921243190765381
# Generator gradients are None
# Epoch 986
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0006071773823350668
# Gen Loss: 6.623711585998535
# Generator gradients are None
# Epoch 987
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0014236376155167818
# Gen Loss: 4.579629898071289
# Generator gradients are None
# Epoch 988
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005947606987319887
# Gen Loss: 7.041179656982422
# Generator gradients are None
# Epoch 989
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005765242967754602
# Gen Loss: 7.206967353820801
# Generator gradients are None
# Epoch 990
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005200165905989707
# Gen Loss: 7.884606838226318
# Generator gradients are None
# Epoch 991
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.0014299771282821894
# Gen Loss: 6.456517696380615
# Generator gradients are None
# Epoch 992
# all_states shape: (117, 4)
# all_labels shape: (117, 1)
# Disc Loss: 0.001809942303225398
# Gen Loss: 6.194397926330566
# Generator gradients are None
# Epoch 993
# all_states shape: (108, 4)
# all_labels shape: (108, 1)
# Disc Loss: 0.0006232743617147207
# Gen Loss: 6.321567535400391
# Generator gradients are None
# Epoch 994
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.0018625307129696012
# Gen Loss: 6.364801406860352
# Generator gradients are None
# Epoch 995
# all_states shape: (119, 4)
# all_labels shape: (119, 1)
# Disc Loss: 0.0024853853974491358
# Gen Loss: 5.868776798248291
# Generator gradients are None
# Epoch 996
# all_states shape: (110, 4)
# all_labels shape: (110, 1)
# Disc Loss: 0.0005184924229979515
# Gen Loss: 7.932585716247559
# Generator gradients are None
# Epoch 997
# all_states shape: (109, 4)
# all_labels shape: (109, 1)
# Disc Loss: 0.0005815978511236608
# Gen Loss: 6.852813720703125
# Generator gradients are None
# Epoch 998
# all_states shape: (116, 4)
# all_labels shape: (116, 1)
# Disc Loss: 0.0010882220230996609
# Gen Loss: 6.231712818145752
# Generator gradients are None
# Epoch 999
# all_states shape: (111, 4)
# all_labels shape: (111, 1)
# Disc Loss: 0.0005015211063437164
# Gen Loss: 8.473404884338379
# Generator gradients are None
# GAIL Policy Evaluation: 9.0
